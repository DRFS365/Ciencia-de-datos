# %% [markdown]
# ## PCA

# %%
# !pip install bioinfokit
# Out:
# Collecting bioinfokit
#   Downloading bioinfokit-2.1.4.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (2.3.3)
# Requirement already satisfied: numpy in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (3.10.6)
# Requirement already satisfied: scipy in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (1.16.3)
# Requirement already satisfied: scikit-learn in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (1.7.2)
# Requirement already satisfied: seaborn in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (0.13.2)
# Collecting matplotlib-venn (from bioinfokit)
#   Downloading matplotlib-venn-1.1.2.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tabulate in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (0.9.0)
# Requirement already satisfied: statsmodels in c:\users\drfs3\anaconda3\lib\site-packages (from bioinfokit) (0.14.5)
# Collecting textwrap3 (from bioinfokit)
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting adjustText (from bioinfokit)
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\drfs3\anaconda3\lib\site-packages (from matplotlib->bioinfokit) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\drfs3\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->bioinfokit) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drfs3\anaconda3\lib\site-packages (from pandas->bioinfokit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drfs3\anaconda3\lib\site-packages (from pandas->bioinfokit) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\drfs3\anaconda3\lib\site-packages (from scikit-learn->bioinfokit) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\drfs3\anaconda3\lib\site-packages (from scikit-learn->bioinfokit) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\drfs3\anaconda3\lib\site-packages (from statsmodels->bioinfokit) (1.0.1)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: bioinfokit, matplotlib-venn
#   Building wheel for bioinfokit (pyproject.toml): started
#   Building wheel for bioinfokit (pyproject.toml): finished with status 'done'
#   Created wheel for bioinfokit: filename=bioinfokit-2.1.4-py3-none-any.whl size=59401 sha256=1db66341e5e6caf764e9fa0dcd2e9c422ed27dafe4f2f416f4a0380b53881c9a
#   Stored in directory: c:\users\drfs3\appdata\local\pip\cache\wheels\fc\51\ce\c3421fa3b4a59ff5310d04e082636ffde48c5575dba558cd49
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45440 sha256=c62122fc6271b2b9b3adbc3656670c2fbc9531aac002a8857f6c01d19e4279fe
#   Stored in directory: c:\users\drfs3\appdata\local\pip\cache\wheels\d1\5f\e6\771479559f992b8398265ebf61f8a3d33ca0b8f75552e06ad2
# Successfully built bioinfokit matplotlib-venn
# Installing collected packages: textwrap3, matplotlib-venn, adjustText, bioinfokit
#
#    ---------- ----------------------------- 1/4 [matplotlib-venn]
#    ------------------------------ --------- 3/4 [bioinfokit]
#    ---------------------------------------- 4/4 [bioinfokit]
#
# Successfully installed adjustText-1.3.0 bioinfokit-2.1.4 matplotlib-venn-1.1.2 textwrap3-0.9.2

# %%
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler 
from bioinfokit.analys import get_data
import numpy as np
import pandas as pd


df = get_data('gexp').data
df.head()
# Out:
#          A         B         C          D          E         F
# 0  4.50570  3.260360 -1.249400   8.898070   8.059550 -0.842803
# 1  3.50856  1.660790 -1.856680  -2.573360  -1.373700  1.196000
# 2  4.44701  3.411940 -1.040870  10.271195  10.517256  0.272272
# 3  2.16003  3.146520  0.982809   9.024300   6.058320 -2.967420
# 4  2.35701  0.452589 -1.910680  12.984239  10.019605 -2.939020

# %%
df_st =  StandardScaler().fit_transform(df)  
pd.DataFrame(df_st, columns=df.columns).head()
# Out:
#           A         B         C         D         E         F
# 0  0.619654  0.448280 -0.240867  2.457058  2.304732 -0.331489
# 1  0.342286 -0.041499 -0.428652 -1.214732 -0.877151  0.474930
# 2  0.603329  0.494693 -0.176385  2.896569  3.133729  0.109563
# 3 -0.032825  0.413423  0.449383  2.497462  1.629707 -1.171850
# 4  0.021968 -0.411444 -0.445350  3.764964  2.965869 -1.160617

# %%
pca_out = PCA().fit(df_st)


pca_out.explained_variance_ratio_
# Out:
# array([0.2978742 , 0.27481252, 0.23181442, 0.19291638, 0.00144353,
#        0.00113895])

# %%
np.cumsum(pca_out.explained_variance_ratio_)
# Out:
# array([0.2978742 , 0.57268672, 0.80450114, 0.99741752, 0.99886105,
#        1.        ])

# %%
print(df.shape)
print(df.columns.values)
# Out:
# (6, 2)
# ['var' 'PC']

# %%
loadings = pca_out.components_
num_pc = pca_out.n_features_in_
pc_list = ["PC"+str(i) for i in list(range(1, num_pc+1))]
loadings_df = pd.DataFrame.from_dict(dict(zip(pc_list, loadings)))
loadings_df['variable'] = df.columns.values
loadings_df = loadings_df.set_index('variable')
loadings_df
# Out:
#                PC1       PC2       PC3       PC4       PC5       PC6
# variable
# A        -0.510898  0.452234  0.227356  0.323464  0.614881  0.008372
# B        -0.085908  0.401197  0.708556 -0.132788 -0.558448 -0.010616
# C         0.477477 -0.100994  0.462437 -0.487951  0.556605  0.007893
# D         0.370318  0.611485 -0.308295 -0.054973 -0.007642  0.625159
# E         0.568491  0.300118 -0.011775  0.484115  0.009382 -0.593425
# F         0.208090 -0.400426  0.370440  0.634234 -0.010111  0.506732

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(loadings_df, annot=True, cmap='Spectral')
plt.show()

# %%
pca_out.explained_variance_
# Out:
# array([1.78994905, 1.65136965, 1.39299071, 1.15924943, 0.0086743 ,
#        0.00684401])

# %%
from bioinfokit.visuz import cluster
cluster.screeplot(obj=[pc_list, pca_out.explained_variance_ratio_])

# %%
cluster.pcaplot(x=loadings[0], y=loadings[1], labels=df.columns.values, 
    var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
    var2=round(pca_out.explained_variance_ratio_[1]*100, 2))

# %%
df = pd.DataFrame({'var':pca_out.explained_variance_ratio_,
             'PC':['PC1','PC2','PC3','PC4','PC5','PC6']})
sns.barplot(x='PC',y="var", 
           data=df, color="c");

# %% [markdown]
# ## Regresión

# %%
from sklearn.datasets import make_blobs
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
num_samples_total = 150
cluster_centers = [(3,3), (3.3, 3.3), (3.6, 3.6), (4, 4)]
num_features = 2


X, _ = make_blobs(n_samples = num_samples_total, centers = cluster_centers, n_features = num_features, center_box=(0, 1), cluster_std = 0.10)

# %%
X.shape
# Out:
# (150, 2)

# %%
X[:,0].reshape(-1,1).shape
# Out:
# (150, 1)

# %%
num_samples_total = 150
cluster_centers = [(3,3), (3.3, 3.3), (3.6, 3.6), (4, 4)]
num_features = 2


X, _ = make_blobs(n_samples = num_samples_total, centers = cluster_centers, n_features = num_features, center_box=(0, 1), cluster_std = 0.10)


y = X[:,1].reshape(-1, 1)
X = X[:,0].reshape(-1, 1)

# %%
reg = LinearRegression().fit(X, y)
print('y = {}x + {}'.format(reg.coef_[0][0], reg.intercept_[0]))
# Out:
# y = 0.924173748619822x + 0.2816330077674931

# %%
y_pred = reg.predict(X)

y_pred
# Out:
# array([[3.64872137],
#        [4.09042883],
#        [3.39188496],
#        [3.85106673],
#        [3.79052801],
#        [4.05733512],
#        [4.04585185],
#        [3.33345741],
#        [4.05190504],
#        [3.63332628],
#        [3.38897815],
#        [3.94584323],
#        [3.40054596],
#        [3.9807802 ],
#        [3.01004722],
#        [4.15184298],
#        [3.72900704],
#        [3.30751985],
#        [3.53943105],
#        [3.03152815],
#        [3.32941546],
#        [3.29767723],
#        [2.97519923],
#        [3.20166437],
#        [3.96034304],
#        [3.25523777],
#        [3.90948044],
#        [3.61936348],
#        [3.1108548 ],
#        [3.94374724],
#        [3.65186606],
#        [3.22471645],
#        [3.06985217],
#        [3.52673273],
#        [3.16732586],
#        [2.97105434],
#        [3.49264643],
#        [3.36444128],
#        [3.55179885],
#        [3.16162751],
#        [4.08137406],
#        [3.00764701],
#        [4.10451319],
#        [3.44047825],
#        [3.35486937],
#        [3.4279626 ],
#        [3.61699533],
#        [3.59675829],
#        [3.98870055],
#        [3.75739081],
#        [3.02070402],
#        [3.64565495],
#        [3.17257145],
#        [4.00442766],
#        [3.22204752],
#        [3.38002014],
#        [2.79436288],
#        [3.43151781],
#        [3.21385526],
#        [3.41017853],
#        [3.44335599],
#        [3.62050448],
#        [3.20885083],
#        [3.72730652],
#        [3.97580011],
#        [3.46818473],
#        [3.29224254],
#        [3.31399237],
#        [3.37010514],
#        [4.16535038],
#        [3.35461202],
#        [2.97929015],
#        [3.66210887],
#        [3.2225241 ],
#        [2.94674169],
#        [3.6790211 ],
#        [3.90280992],
#        [3.47753449],
#        [3.21639441],
#        [3.65713814],
#        [3.51026902],
#        [3.88092357],
#        [3.5642454 ],
#        [3.88399727],
#        [3.64435719],
#        [4.06343203],
#        [2.96734727],
#        [3.03985169],
#        [4.1998402 ],
#        [2.92310786],
#        [3.37230893],
#        [3.4912026 ],
#        [3.10113843],
#        [3.07640519],
#        [2.9832782 ],
#        [3.49638099],
#        [3.04743982],
#        [3.47263855],
#        [4.00790283],
#        [3.33915806],
#        [3.88813347],
#        [3.56964896],
#        [3.81503075],
#        [2.94745739],
#        [3.04348032],
#        [3.96237276],
#        [3.71370751],
#        [3.03653527],
#        [2.89840614],
#        [3.2825592 ],
#        [3.16901128],
#        [3.10373932],
#        [3.96961525],
#        [3.59849852],
#        [3.96966527],
#        [3.31880493],
#        [3.33415816],
#        [3.95104832],
#        [3.0305931 ],
#        [3.34759781],
#        [3.56601994],
#        [3.44441051],
#        [3.32539727],
#        [3.05714154],
#        [4.09956868],
#        [3.78253059],
#        [3.09974601],
#        [3.00387382],
#        [3.62097875],
#        [4.03535758],
#        [3.99320528],
#        [3.45049187],
#        [3.05114929],
#        [3.50094928],
#        [3.12714224],
#        [4.18256618],
#        [3.94746187],
#        [3.33040043],
#        [3.2360851 ],
#        [3.11535094],
#        [3.02898969],
#        [3.43887942],
#        [3.0684079 ],
#        [2.94306125],
#        [3.29909147],
#        [3.2446931 ],
#        [3.59363179],
#        [3.86423832],
#        [3.54340581],
#        [4.02520856]])

# %%
plt.scatter(X, y, marker="o", picker=True)
plt.plot(X, y_pred, color='red')
plt.title(f'Muestras and ajuste OLS')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
