# %% [markdown]
# # El teorema del límite central
# ### Variable aleatoria exponencial

# %% [markdown]
# ### Distribución exponencial es una variable aleatoria cuya probabilidad se encuentra como sigue:
# $$P(T<t)=\int_{0}^{t} \lambda e^{-\lambda x}dx $$

# %%
import numpy as np
import pandas as pd
import scipy 
import seaborn as sns

# %%
np.random.exponential(1)
# Out:
# 0.07701898466719748

# %%
np.random.binomial(1000, 0.3)
# Out:
# 318

# %%
type([ ])
# Out:
# list

# %%
type(range(7,10))
# Out:
# range

# %%
np.array([1,2,3])+np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
alumnos = {"Nina": [22, 1.62, 53],
           "Azul": [20, 1.60, 48],
           "Mariana":[20, 1.62, 53]} 

alumnos
# Out:
# {'Nina': [22, 1.62, 53], 'Azul': [20, 1.6, 48], 'Mariana': [20, 1.62, 53]}

# %%
alumnos["Nina"]
# Out:
# [22, 1.62, 53]

# %%
alumnos["Leonardo"]=[22, 1.75, 65]

# %%
alumnos
# Out:
# {'Nina': [22, 1.62, 53],
#  'Azul': [20, 1.6, 48],
#  'Mariana': [20, 1.62, 53],
#  'Leonardo': [22, 1.75, 65]}

# %%
I = ["edad", "estatura", "peso"]

dfalumnos = pd.DataFrame(alumnos, index=I)  

dfalumnos
# Out:
#            Nina  Azul  Mariana  Leonardo
# edad      22.00  20.0    20.00     22.00
# estatura   1.62   1.6     1.62      1.75
# peso      53.00  48.0    53.00     65.00

# %%
dfalumnos.iloc[0].mean()
# Out:
# np.float64(21.0)

# %%
tamaño = 2 

df = pd.DataFrame(index=["M1", "M2" ] )

for i in range(1,51):
  muestra_exponencial = np.random.exponential(4, tamaño)

  col = f"muestra {i}" 

  df[col] = muestra_exponencial

# %%
df
# Out:
#     muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# M1   0.952677   7.977544   1.726254   1.575755   0.037399   2.699017
# M2   0.580837   7.808928   3.119831   8.013706   0.846344   2.439057
#
#     muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 41  muestra 42  \
# M1   0.341016   5.401546   1.052700    2.306927  ...    7.011111    6.213804
# M2   3.682449   3.489607   1.151789    0.710735  ...    0.654473    2.144940
#
#     muestra 43  muestra 44  muestra 45  muestra 46  muestra 47  muestra 48  \
# M1    1.972343    0.106154    5.285152    9.778990    0.866784    0.166200
# M2    6.378888   19.994377   15.014801    4.657473    0.138663    0.135826
#
#     muestra 49  muestra 50
# M1    1.785907    2.723741
# M2    2.163306    0.110076
#
# [2 rows x 50 columns]

# %%
import seaborn as sns

muestra_exponencial_medias = df.mean()

muestra_exponencial_medias
# Out:
# muestra 1      0.766757
# muestra 2      7.893236
# muestra 3      2.423043
# muestra 4      4.794731
# muestra 5      0.441872
# muestra 6      2.569037
# muestra 7      2.011732
# muestra 8      4.445577
# muestra 9      1.102244
# muestra 10     1.508831
# muestra 11    10.859148
# muestra 12     0.803862
# muestra 13     5.889439
# muestra 14     5.714714
# muestra 15     1.476385
# muestra 16     6.373669
# muestra 17     1.834048
# muestra 18     5.882542
# muestra 19     4.495968
# muestra 20     1.494301
# muestra 21     2.312104
# muestra 22    12.028820
# muestra 23     4.042007
# muestra 24     1.135553
# muestra 25     4.327869
# muestra 26     2.661707
# muestra 27     4.061428
# muestra 28     5.615072
# muestra 29     2.393850
# muestra 30     1.813641
# muestra 31     4.645010
# muestra 32     0.663573
# muestra 33     5.203998
# muestra 34     2.960926
# muestra 35     0.750143
# muestra 36     0.895545
# muestra 37     3.029692
# muestra 38     3.258512
# muestra 39     7.373338
# muestra 40     1.908120
# muestra 41     3.832792
# muestra 42     4.179372
# muestra 43     4.175615
# muestra 44    10.050266
# muestra 45    10.149977
# muestra 46     7.218232
# muestra 47     0.502724
# muestra 48     0.151013
# muestra 49     1.974607
# muestra 50     1.416908
# dtype: float64

# %%
sns.histplot(muestra_exponencial_medias);

# %%
tamaño=500

df500 = pd.DataFrame()

for i in range(1, 51):
    exponential_sample = np.random.exponential(4, tamaño)
    col = f'sample {i}'
    df500[col] = exponential_sample


df500_exp_medias = pd.DataFrame(df500.mean(),columns=['Muestra de las medias'])
sns.histplot(df500_exp_medias);
