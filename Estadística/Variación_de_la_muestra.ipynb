# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
# %matplotlib inline

# %%
#Función para generar una muestra aleatoria de una distribución normal con media 10 y DS 5, y calcular la media y DS de la muestra.
muestra = pd.DataFrame(np.random.normal(10, 5, size=30))
print('la media de la muestra es ', muestra[0].mean())
print('la DS de la muestra es ', muestra[0].std(ddof=1))
# Out:
# la media de la muestra es  10.857005360977128
# la DS de la muestra es  4.141712646032197

# %%
meanlist = []
for t in range(10000):
    muestra = pd.DataFrame(np.random.normal(10, 5, size=30))
    meanlist.append(muestra[0].mean())

# %%
colleccion = pd.DataFrame()
colleccion['meanlist'] = meanlist

# %%
colleccion.head()
# Out:
#     meanlist
# 0  10.055570
# 1   9.588900
# 2   9.717435
# 3  11.255606
# 4   9.930431

# %%
colleccion['meanlist'].hist(bins=100, density=True, stacked=True,figsize=(10,8))
# Out:
# <Axes: >
